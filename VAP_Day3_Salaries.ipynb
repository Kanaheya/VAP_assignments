# %% [markdown]
# # Name:Kanaheya Jadhav
# Roll no.: 2214058

# %%
import pandas as pd
import numpy as np

# %%
sal=pd.read_csv(r"Salaries.csv")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7784\52584285.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   sal=pd.read_csv(r"Salaries.csv")

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# # DATA CLEANING

# %%
sal=sal.drop_duplicates()

# %%
sal.drop(sal[sal["BasePay"]== 'Not Provided'].index,inplace=True)

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148647  148648     Joann Anderson
# 148648  148649        Leon Walker
# 148649  148650      Roy I Tillery
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# ...

# %%
sal.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148650.000000  148650.000000     148650.000000  148650.000000    0.0
# mean    74325.500047   74770.333901      93695.075969    2012.522603    NaN
# std     42911.703176   50516.196009      62792.497391       1.117526    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37163.250000   36169.955000      44073.337500    2012.000000    NaN
# 50%     74325.500000   71427.240000      92406.020000    2013.000000    NaN
# 75%    111487.750000  105842.960000     132877.992500    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148650 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148650 non-null  int64
#  1   EmployeeName      148650 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148045 non-null  object
#  4   OvertimePay       148650 non-null  object
#  5   OtherPay          148650 non-null  object
#  6   Benefits          112491 non-null  object
#  7   TotalPay          148650 non-null  float64
#  8   TotalPayBenefits  148650 non-null  float64
#  9   Year              148650 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148650 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 15.9+ MB

# %%
sal=sal.drop(columns='Notes')

# %%
sal['Benefits'] = pd.to_numeric(sal['Benefits'], errors='coerce').astype('float64')
sal['BasePay'] = pd.to_numeric(sal['BasePay'], errors='coerce').astype('float64')
sal['OvertimePay'] = pd.to_numeric(sal['OvertimePay'], errors='coerce').astype('float64')
sal['OtherPay'] = pd.to_numeric(sal['OtherPay'], errors='coerce').astype('float64')
sal['TotalPay'] = pd.to_numeric(sal['TotalPay'], errors='coerce').astype('float64')

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148647  148648     Joann Anderson
# 148648  148649        Leon Walker
# 148649  148650      Roy I Tillery
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148645                       Human Services Technician       0.00
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148650 entries, 0 to 148653
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148650 non-null  int64
#  1   EmployeeName      148650 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148650 non-null  float64
#  8   TotalPayBenefits  148650 non-null  float64
#  9   Year              148650 non-null  int64
#  10  Agency            148650 non-null  object
#  11  Status            38119 non-null   object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 14.7+ MB

# %% [markdown]
# # Exercise Question

# %% [markdown]
# # Check the head of the DataFrame.

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year         Agency Status
# 0  2011  San Francisco    NaN
# ...

# %% [markdown]
# # What is the average BasePay ?

# %%
sal['BasePay'].mean()
# Out:
# 66325.4488404877

# %% [markdown]
# # What is the highest amount of OvertimePay in the dataset ?

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# # What is the job title of JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll).

# %%
sal.loc[(sal['EmployeeName']=='JOSEPH DRISCOLL')]['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# # How much does JOSEPH DRISCOLL make (including benefits)?

# %%
sal.loc[(sal['EmployeeName']=='JOSEPH DRISCOLL')]['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# # What is the name of highest paid person (including benefits)?

# %%
sal.loc[(sal['TotalPayBenefits']==sal['TotalPayBenefits'].max())]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year         Agency Status
# 0  2011  San Francisco    NaN

# %% [markdown]
# # What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?

# %%
a=sal['TotalPayBenefits'].min()
a
sal.loc[(sal['TotalPayBenefits']==0.0)]
# Out:
#             Id            EmployeeName  \
# 36156    36157          PAULETTE ADAMS
# 36157    36158           KAUKAB MOHSIN
# 36158    36159      JOSEPHINE MCCREARY
# 148626  148627           Paulet Gaines
# 148627  148628        Brett A Lundberg
# 148628  148629          Mark W Mcclure
# 148629  148630       Elizabeth Iniguez
# 148630  148631            Randy J Keys
# 148631  148632         Andre M Johnson
# 148632  148633  Sharon D Owens-Webster
# 148633  148634        Edward Ferdinand
# 148634  148635          David M Turner
# 148635  148636     James S Kibblewhite
# 148636  148637           Andrew J Enzi
# 148637  148638        Kadeshra D Green
# 148638  148639    Lennard B Hutchinson
# 148639  148640       Richard A Talbert
# 148640  148641      Charlene D Mccully
# 148641  148642   Raphael Marquis Goins
# 148642  148643       Dominic C Marquez
# 148643  148644              Kim Brewer
# 148644  148645            Randy D Winn
# 148645  148646        Carolyn A Wilson
# ...

# %% [markdown]
# # What was the average (mean) BasePay of all employees per year? (2011-2014) ?

# %%
by_comp = sal.groupby(by='Year')
by_comp['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# # How many unique job titles are there?

# %%
sal['JobTitle'].nunique()
# Out:
# 2158

# %% [markdown]
# # What are the top 5 most common jobs?

# %%
by_comp = sal.groupby(by='JobTitle')
by_comp['JobTitle'].count().nlargest()
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# # How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?)

# %%
sum(sal.loc[(sal['Year']==2013)]['JobTitle'].value_counts()==1)
# Out:
# 202

# %% [markdown]
# # How many people have the word Chief in their job title? (This is pretty tricky)

# %%
sal['JobTitle'].str.lower().str.count("chief").sum()
# Out:
# 627

# %% [markdown]
# # Bonus: Is there a correlation between length of the Job Title string and Salary?

# %%
sal['length']=sal['JobTitle'].apply(len)
sal[['length','TotalPayBenefits']].corr()
# Out:
#                    length  TotalPayBenefits
# length            1.00000          -0.03692
# TotalPayBenefits -0.03692           1.00000
